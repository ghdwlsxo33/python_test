# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=np.random.rand(3)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.09782087 0.57590111 0.78702891]

# %%
seri=pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0    0.097821
# 1    0.575901
# 2    0.787029
# dtype: float64

# %%
seri.plot()
# Out:
# <Axes: >
